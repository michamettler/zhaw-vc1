# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
def verify(img1_path, img2_path):
    img1 = cv2.imread(img1_path)
    img2 = cv2.imread(img2_path)

    plt.imshow(img1[:,:,::-1])
    plt.show()
    plt.imshow(img2[:,:,::-1])
    plt.show()

    result = DeepFace.verify(img1_path, img2_path)

    if result['verified'] == True:
        print('they are the same')
    else:
        print('they are different')

# %%
verify ("ressource/davis.jpg", "ressource/davis2.jpg")
# Out:
# {'verified': True, 'distance': 0.5117609245894551, 'threshold': 0.68, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 886, 'y': 1258, 'w': 838, 'h': 838, 'left_eye': (1465, 1566), 'right_eye': (1107, 1562)}, 'img2': {'x': 191, 'y': 548, 'w': 772, 'h': 772, 'left_eye': None, 'right_eye': None}}, 'time': 11.6}
# they are the same
