# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
import json

# %%
img1_path = 'ressource/fiennes2.png'

img1 = cv2.imread(img1_path)

plt.imshow(img1[:,:,::-1])
plt.show()

# %%
demography = DeepFace.analyze(img1_path, actions = ['emotion', 'age', 'gender', 'race'])
demography
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  4.59it/s]
# [{'emotion': {'angry': 4.674583300948143,
#    'disgust': 0.0013602644685306586,
#    'fear': 21.274544298648834,
#    'happy': 28.588643670082092,
#    'sad': 2.2603319957852364,
#    'surprise': 0.4744770471006632,
#    'neutral': 42.7260547876358},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 295,
#    'y': 118,
#    'w': 268,
#    'h': 268,
#    'left_eye': (455, 213),
#    'right_eye': (376, 236)},
#   'face_confidence': 0.94,
#   'age': 46,
#   'gender': {'Woman': 9.719525451146183e-05, 'Man': 99.99990463256836},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.0005525823075259433,
#    'indian': 0.009805176237190662,
#    'black': 0.00013236983008935418,
#    'white': 90.13694407188225,
#    'middle eastern': 8.071711131538288,
#    'latino hispanic': 1.780856240493803},
#   'dominant_race': 'white'}]
